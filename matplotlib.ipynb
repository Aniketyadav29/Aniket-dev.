# %% [markdown]
# <a href="https://colab.research.google.com/github/Aniketyadav29/Aniket-dev./blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Matplotlib**
#
# Matplotlib is the most popular python library used for creating data visualization . it converts numerical data into meaningful charts and graphs that help users analyze trends ,patterns ,and comparisions.

# %% [markdown]
# **Features of Matplotlib**
#
# 1.Open Source
#
# 2.Highly Customize
#
# 3.Supports 20+ Chart Types
#
# 4.Publication Quality charts
#
# 5.works perfectly with NumPy and Pandas
#
# 6.can save images in PNG,JPG,SVG

# %% [markdown]
# # **Installation**
#
# pip install matplotlib

# %%
# import matplotlib

import matplotlib.pyplot as plt

# %%
# First graph
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[2,4,6,8,10]
plt.plot(x,y)
plt.show()

# %%
# First Graph
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[21,4,5,34,10]
plt.plot(x,y)
plt.show()
plt.savefig('first_graph.png')
plt.savefig('first_graph.pdf')
plt.savefig('first_graph.jpg')

# %%
# First Graph using Matplotlib

import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 30, 25]

# Create Figure
plt.figure(figsize=(8, 5))

# Plot Line Graph
plt.plot(
    x,
    y,
    marker='o',
    linestyle='-',
    linewidth=2,
    color='blue',
    label='Sales'
)

# Title and Labels
plt.title("First Line Graph", fontsize=16)
plt.xlabel("X Values", fontsize=12)
plt.ylabel("Y Values", fontsize=12)


# Save the graph
plt.savefig("first_graph.png", dpi=300, bbox_inches="tight")
plt.savefig("first_graph.jpg", dpi=300, bbox_inches="tight")
plt.savefig("first_graph.pdf", bbox_inches="tight")

# Display the graph
plt.show()

# Close the figure
plt.close()

# %%
# First Graph using Matplotlib

import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [4, 45,15, 76, 25]

# Create Figure
plt.figure(figsize=(8, 5))

# Plot Line Graph
plt.plot(
    x,
    y,
    marker='o',
    linestyle='-',
    linewidth=2,
    color='blue',
    label='Sales'
)

# Title and Labels
plt.title("First Line Graph", fontsize=16)
plt.xlabel("X Values", fontsize=12)
plt.ylabel("Y Values", fontsize=12)


# Save the graph
plt.savefig("first_graph.png", dpi=300, bbox_inches="tight")
plt.savefig("first_graph.jpg", dpi=300, bbox_inches="tight")
plt.savefig("first_graph.pdf", bbox_inches="tight")

# Display the graph
plt.show()

# Close the figure
plt.close()
